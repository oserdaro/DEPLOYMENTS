# %%
import pandas as pd      
import numpy as np 
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print(" r2_score:", score, "\n","mae:", mae, "\n","mse:",mse, "\n","rmse:",rmse)

# %%
df = pd.read_csv("Advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
X= df.drop("sales", axis=1)
y= df["sales"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
filename = 'my_model'
pickle.dump(model, open(filename, 'wb'))

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
y_pred = model.predict(X_test)
eval_metrics(y_test, y_pred)
# Out:
#  r2_score: 0.8609466508230368
#  mae: 1.5116692224549084
#  mse: 3.79679723671522
#  rmse: 1.9485372043446387

# %% [markdown]
# **deployment**

# %%
final_model = pickle.load(open('my_model', 'rb'))

# %%
columns=list(X.columns)
columns
# Out:
# ['TV', 'radio', 'newspaper']

# %%
my_dict = {
    "TV": 150,
    "radio": 25,
    "newspaper": 30,
}

# %%
df = pd.DataFrame.from_dict([my_dict])

# %%
df
# Out:
#     TV  radio  newspaper
# 0  150     25         30

# %%
prediction = final_model.predict(df)
print(prediction)
# Out:
# [14.50650223]

# %%
print("The estimated value of sales is {}. ".format(int(prediction[0])))
# Out:
# The estimated value of sales is 14.

# %%
conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\serda\anaconda3
# DA                       C:\Users\serda\anaconda3\envs\DA
# DL                       C:\Users\serda\anaconda3\envs\DL
# ML                    *  C:\Users\serda\anaconda3\envs\ML
# DL                       c:\Users\serda\anaconda3\envs\DL
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ---------------
# absl-py                      2.1.0
# annotated-types              0.6.0
# anyascii                     0.3.2
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        23.2.0
# autocorrect                  2.6.1
# backcall                     0.2.0
# beartype                     0.17.2
# Bottleneck                   1.3.7
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# chart-studio                 1.1.0
# click                        8.1.7
# colorama                     0.4.6
# colorlover                   0.3.0
# comm                         0.1.4
# contourpy                    1.2.0
# contractions                 0.1.73
# cufflinks                    0.17.3
# cycler                       0.11.0
# daal4py                      2023.1.1
# debugpy                      1.6.7.post1
# decorator                    5.1.1
# et-xmlfile                   1.1.0
# executing                    1.2.0
# fastjsonschema               2.19.1
# filelock                     3.13.4
# flatbuffers                  24.3.25
# fonttools                    4.25.0
# fsspec                       2024.3.1
# gast                         0.5.4
# google-pasta                 0.2.0
# griffe                       0.42.1
# grpcio                       1.62.2
# h5py                         3.11.0
# huggingface-hub              0.22.2
# idna                         3.6
# imbalanced-learn             0.12.2
# importlib_metadata           7.0.2
# importlib_resources          6.3.2
# ipykernel                    6.25.1
# ipython                      8.14.0
# ipywidgets                   8.1.2
# jedi                         0.19.0
# Jinja2                       3.1.3
# joblib                       1.2.0
# jsonschema                   4.21.1
# jsonschema-specifications    2023.12.1
# jupyter_client               8.3.0
# jupyter_core                 5.3.1
# jupyterlab-widgets           3.0.10
# keras                        3.3.3
# kiwisolver                   1.4.4
# libclang                     18.1.1
# Markdown                     3.6
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.3
# matplotlib                   3.8.0
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# mkl-fft                      1.3.8
# mkl-random                   1.2.4
# mkl-service                  2.4.0
# ml-dtypes                    0.3.2
# munkres                      1.1.4
# namex                        0.0.8
# nbformat                     5.10.3
# nest-asyncio                 1.5.7
# nltk                         3.8.1
# numexpr                      2.8.7
# numpy                        1.24.3
# openpyxl                     3.0.10
# opt-einsum                   3.3.0
# optree                       0.11.0
# packaging                    23.1
# pandas                       2.1.4
# parso                        0.8.3
# patsy                        0.5.3
# pickleshare                  0.7.5
# pillow                       10.2.0
# pip                          23.3.1
# platformdirs                 3.10.0
# plotly                       5.19.0
# plum-dispatch                2.3.2
# polars                       0.20.16
# prompt-toolkit               3.0.39
# protobuf                     4.25.3
# psutil                       5.9.5
# pure-eval                    0.2.2
# pyahocorasick                2.1.0
# pyarrow                      15.0.2
# pydantic                     2.6.4
# pydantic_core                2.16.3
# Pygments                     2.16.1
# pyparsing                    3.0.9
# python-dateutil              2.8.2
# pytz                         2023.3.post1
# pywin32                      306
# PyYAML                       6.0.1
# pyzmq                        25.1.1
# quartodoc                    0.7.2
# referencing                  0.34.0
# regex                        2024.4.16
# requests                     2.31.0
# retrying                     1.3.4
# rich                         13.7.1
# rpds-py                      0.18.0
# safetensors                  0.4.3
# scikit-learn                 1.3.0
# scikit-learn-intelex         20230426.121932
# scikit-plot                  0.3.7
# scipy                        1.11.4
# seaborn                      0.13.0
# setuptools                   68.2.2
# six                          1.16.0
# skimpy                       0.0.14
# sphobjinv                    2.3.1
# stack-data                   0.6.2
# statsmodels                  0.14.0
# tabulate                     0.9.0
# tenacity                     8.2.2
# tensorboard                  2.16.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.16.1
# tensorflow-intel             2.16.1
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# textsearch                   0.0.24
# threadpoolctl                2.2.0
# tokenizers                   0.15.2
# tornado                      6.3.3
# tqdm                         4.66.2
# traitlets                    5.9.0
# transformers                 4.37.2
# typeguard                    4.1.5
# typing_extensions            4.10.0
# tzdata                       2023.3
# urllib3                      2.2.1
# watchdog                     4.0.0
# wcwidth                      0.2.6
# Werkzeug                     3.0.2
# wheel                        0.41.2
# widgetsnbextension           4.0.10
# wordcloud                    1.9.3
# wrapt                        1.16.0
# yellowbrick                  1.5
# zipp                         3.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Collecting scikit-learn==1.2.2 (from -r requirements.txt (line 1))
#   Using cached scikit_learn-1.2.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting streamlit==1.22.0 (from -r requirements.txt (line 2))
#   Using cached streamlit-1.22.0-py2.py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (2.2.0)
# Collecting altair<5,>=3.2.0 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached altair-4.2.2-py3-none-any.whl.metadata (13 kB)
# Collecting blinker>=1.0.0 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached blinker-1.8.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools>=4.0 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click>=7.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (7.0.2)
# Requirement already satisfied: packaging>=14.1 in c:\users\serda\appdata\roaming\python\python311\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (10.2.0)
# Collecting protobuf<4,>=3.12 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (15.0.2)
# Collecting pympler>=0.9 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached Pympler-1.0.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil in c:\users\serda\appdata\roaming\python\python311\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: requests>=2.4 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (8.2.2)
# Collecting toml (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (4.10.0)
# Collecting tzlocal>=1.1 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators>=0.2 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached validators-0.28.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting gitpython!=3.1.19 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck>=0.1.dev5 (from streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached pydeck-0.9.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\serda\appdata\roaming\python\python311\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (6.3.3)
# Requirement already satisfied: watchdog in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (4.0.0)
# Collecting entrypoints (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jinja2 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (4.21.1)
# Collecting toolz (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\serda\appdata\roaming\python\python311\site-packages (from click>=7.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19->streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from importlib-metadata>=1.4->streamlit==1.22.0->-r requirements.txt (line 2)) (3.18.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from pandas<3,>=0.25->streamlit==1.22.0->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from pandas<3,>=0.25->streamlit==1.22.0->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\serda\appdata\roaming\python\python311\site-packages (from python-dateutil->streamlit==1.22.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from rich>=10.11.0->streamlit==1.22.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\serda\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->streamlit==1.22.0->-r requirements.txt (line 2)) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.22.0->-r requirements.txt (line 2))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\serda\anaconda3\envs\ml\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.1.2)
# Using cached scikit_learn-1.2.2-cp311-cp311-win_amd64.whl (8.3 MB)
# Using cached streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
# Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# Using cached blinker-1.8.1-py3-none-any.whl (9.5 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Using cached pydeck-0.9.0-py2.py3-none-any.whl (6.9 MB)
# Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Using cached validators-0.28.1-py3-none-any.whl (39 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: validators, tzlocal, toolz, toml, smmap, pympler, protobuf, entrypoints, cachetools, blinker, scikit-learn, pydeck, gitdb, gitpython, altair, streamlit
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed altair-4.2.2 blinker-1.8.1 cachetools-5.3.3 entrypoints-0.4 gitdb-4.0.11 gitpython-3.1.43 protobuf-3.20.3 pydeck-0.9.0 pympler-1.0.1 scikit-learn-1.2.2 smmap-5.0.1 streamlit-1.22.0 toml-0.10.2 toolz-0.12.1 tzlocal-5.2 validators-0.28.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ---------------
# absl-py                      2.1.0
# altair                       4.2.2
# annotated-types              0.6.0
# anyascii                     0.3.2
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        23.2.0
# autocorrect                  2.6.1
# backcall                     0.2.0
# beartype                     0.17.2
# blinker                      1.8.1
# Bottleneck                   1.3.7
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# chart-studio                 1.1.0
# click                        8.1.7
# colorama                     0.4.6
# colorlover                   0.3.0
# comm                         0.1.4
# contourpy                    1.2.0
# contractions                 0.1.73
# cufflinks                    0.17.3
# cycler                       0.11.0
# daal4py                      2023.1.1
# debugpy                      1.6.7.post1
# decorator                    5.1.1
# entrypoints                  0.4
# et-xmlfile                   1.1.0
# executing                    1.2.0
# fastjsonschema               2.19.1
# filelock                     3.13.4
# flatbuffers                  24.3.25
# fonttools                    4.25.0
# fsspec                       2024.3.1
# gast                         0.5.4
# gitdb                        4.0.11
# GitPython                    3.1.43
# google-pasta                 0.2.0
# griffe                       0.42.1
# grpcio                       1.62.2
# h5py                         3.11.0
# huggingface-hub              0.22.2
# idna                         3.6
# imbalanced-learn             0.12.2
# importlib_metadata           7.0.2
# importlib_resources          6.3.2
# ipykernel                    6.25.1
# ipython                      8.14.0
# ipywidgets                   8.1.2
# jedi                         0.19.0
# Jinja2                       3.1.3
# joblib                       1.2.0
# jsonschema                   4.21.1
# jsonschema-specifications    2023.12.1
# jupyter_client               8.3.0
# jupyter_core                 5.3.1
# jupyterlab-widgets           3.0.10
# keras                        3.3.3
# kiwisolver                   1.4.4
# libclang                     18.1.1
# Markdown                     3.6
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.3
# matplotlib                   3.8.0
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# mkl-fft                      1.3.8
# mkl-random                   1.2.4
# mkl-service                  2.4.0
# ml-dtypes                    0.3.2
# munkres                      1.1.4
# namex                        0.0.8
# nbformat                     5.10.3
# nest-asyncio                 1.5.7
# nltk                         3.8.1
# numexpr                      2.8.7
# numpy                        1.24.3
# openpyxl                     3.0.10
# opt-einsum                   3.3.0
# optree                       0.11.0
# packaging                    23.1
# pandas                       2.1.4
# parso                        0.8.3
# patsy                        0.5.3
# pickleshare                  0.7.5
# pillow                       10.2.0
# pip                          23.3.1
# platformdirs                 3.10.0
# plotly                       5.19.0
# plum-dispatch                2.3.2
# polars                       0.20.16
# prompt-toolkit               3.0.39
# protobuf                     3.20.3
# psutil                       5.9.5
# pure-eval                    0.2.2
# pyahocorasick                2.1.0
# pyarrow                      15.0.2
# pydantic                     2.6.4
# pydantic_core                2.16.3
# pydeck                       0.9.0
# Pygments                     2.16.1
# Pympler                      1.0.1
# pyparsing                    3.0.9
# python-dateutil              2.8.2
# pytz                         2023.3.post1
# pywin32                      306
# PyYAML                       6.0.1
# pyzmq                        25.1.1
# quartodoc                    0.7.2
# referencing                  0.34.0
# regex                        2024.4.16
# requests                     2.31.0
# retrying                     1.3.4
# rich                         13.7.1
# rpds-py                      0.18.0
# safetensors                  0.4.3
# scikit-learn                 1.2.2
# scikit-learn-intelex         20230426.121932
# scikit-plot                  0.3.7
# scipy                        1.11.4
# seaborn                      0.13.0
# setuptools                   68.2.2
# six                          1.16.0
# skimpy                       0.0.14
# smmap                        5.0.1
# sphobjinv                    2.3.1
# stack-data                   0.6.2
# statsmodels                  0.14.0
# streamlit                    1.22.0
# tabulate                     0.9.0
# tenacity                     8.2.2
# tensorboard                  2.16.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.16.1
# tensorflow-intel             2.16.1
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# textsearch                   0.0.24
# threadpoolctl                2.2.0
# tokenizers                   0.15.2
# toml                         0.10.2
# toolz                        0.12.1
# tornado                      6.3.3
# tqdm                         4.66.2
# traitlets                    5.9.0
# transformers                 4.37.2
# typeguard                    4.1.5
# typing_extensions            4.10.0
# tzdata                       2023.3
# tzlocal                      5.2
# urllib3                      2.2.1
# validators                   0.28.1
# watchdog                     4.0.0
# wcwidth                      0.2.6
# Werkzeug                     3.0.2
# wheel                        0.41.2
# widgetsnbextension           4.0.10
# wordcloud                    1.9.3
# wrapt                        1.16.0
# yellowbrick                  1.5
# zipp                         3.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run my_app.py
# Out:
# ^C
